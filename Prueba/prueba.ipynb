# %%
import pandas as pd

# Crear una serie de ejemplo sobre fuentes de energías renovables
fuentes_energia = pd.Series({
    "Solar": 25.3,
    "Eólica": 18.7,
    "Hidráulica": 35.5,
    "Biomasa": 12.1,
    "Geotérmica": 3.4
})
print("Producción de energía por fuente (en GW):")
print(fuentes_energia)

# Crear un Diccionario sobre proyectos de energías renovables
proyectos_renovables = {
    "Proyecto": ["Solar Andes", "Viento Pacífico", "Hidro Amazonas", "Bio Norte"],
    "Capacidad (MW)": [150, 200, 500, 100],
    "Ubicación": ["Chile", "Perú", "Brasil", "Colombia"]
}

# Convertir el Diccionario en un Dataframe
df = pd.DataFrame(proyectos_renovables)

print("\nProyectos de energías renovables:")
print(df)
# Out:
# Producción de energía por fuente (en GW):
# Solar         25.3
# Eólica        18.7
# Hidráulica    35.5
# Biomasa       12.1
# Geotérmica     3.4
# dtype: float64
#
# Proyectos de energías renovables:
#           Proyecto  Capacidad (MW) Ubicación
# 0      Solar Andes             150     Chile
# 1  Viento Pacífico             200      Perú
# 2   Hidro Amazonas             500    Brasil
# 3        Bio Norte             100  Colombia

# %%
# Captura de los datos
valor_inicial = 30
cambio = 10

# Cálculos
valor_final = valor_inicial + cambio

# Visualización de los resultados

print(f"El resultado es: {valor_final}")
# Out:
# El resultado es: 40
